# %%
import pandas as pd

# %%
companies = pd.read_excel('crunchbase_monthly_export_d43b4klo2ade53.xlsx', sheet_name='Companies')
# Out:
# /Users/yael/anaconda3/lib/python3.11/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
companies[20000:20050]
# Out:
#                                         permalink  \
# 20000                      /organization/ijj-corp
# 20001                        /organization/ijoule
# 20002                      /organization/ijukebox
# 20003                         /organization/ikaaz
# 20004        /organization/ikang-healthcare-group
# 20005          /organization/ikano-communications
# 20006                        /organization/ikanos
# 20007                        /organization/ikaria
# 20008                    /organization/ikasystems
# 20009                        /organization/ikegps
# 20010                /organization/iken-solutions
# 20011                      /organization/ikerchem
# 20012                   /organization/iklax-media
# 20013                        /organization/iknowl
# 20014                           /organization/iko
# 20015                          /organization/ikoa
# 20016            /organization/ikon-semiconductor
# 20017                      /organization/ikonisys
# ...

# %%
companies[companies['country_code'] == 'USA'].shape
# Out:
# (28793, 18)

# %%
companies['homepage_url'].isna().sum()
# Out:
# 3449

# %%
companies.shape
# Out:
# (49438, 18)

# %%
companies[companies['founded_year'] > 2009].shape
# Out:
# (19402, 18)

# %%
companies[companies['founded_year'] <= 2009].shape
# Out:
# (19080, 18)

# %%
companies['founded_year'].count()
# Out:
# 38482

# %%
companies['status'].value_counts()
# Out:
# status
# operating    41829
# acquired      3692
# closed        2603
# Name: count, dtype: int64

# %%
rounds = pd.read_excel('crunchbase_monthly_export_d43b4klo2ade53.xlsx', sheet_name='Rounds')
# Out:
# /Users/yael/anaconda3/lib/python3.11/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
rounds.head()
# Out:
#                  company_permalink        company_name  \
# 0            /organization/waywire            #waywire
# 1  /organization/tv-communications  &TV Communications
# 2  /organization/tv-communications  &TV Communications
# 3    /organization/rock-your-paper   'Rock' Your Paper
# 4   /organization/in-touch-network   (In)Touch Network
#
#                                company_category_list company_market  \
# 0         |Entertainment|Politics|Social Media|News|           News
# 1                                            |Games|          Games
# 2                                            |Games|          Games
# 3                             |Publishing|Education|     Publishing
# 4  |Electronics|Guides|Coffee|Restaurants|Music|i...    Electronics
#
#   company_country_code company_state_code company_region company_city  \
# 0                  USA                 NY  New York City     New York
# 1                  USA                 CA    Los Angeles  Los Angeles
# ...

# %%
rounds.shape
# Out:
# (83870, 16)

# %%
investments = pd.read_excel('crunchbase_monthly_export_d43b4klo2ade53.xlsx', sheet_name='Investments')
# Out:
# /Users/yael/anaconda3/lib/python3.11/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
investments.head()
# Out:
#                      company_permalink           company_name  \
# 0         /organization/test-company-3           test company
# 1  /organization/andrewburnett-com-ltd  AndrewBurnett.com Ltd
# 2               /organization/abo-data               ABO Data
# 3               /organization/abo-data               ABO Data
# 4                   /organization/ikro                   Ikro
#
#                                company_category_list       company_market  \
# 0                                                NaN                  NaN
# 1  |Internet|SEO|Services|Public Relations|Social...             Internet
# 2                              |Enterprise Software|  Enterprise Software
# 3                              |Enterprise Software|  Enterprise Software
# 4                                                NaN                  NaN
#
#   company_country_code company_state_code company_region company_city  \
# 0                  ARE                NaN          Dubai        Dubai
# ...

# %%
investments.shape
# Out:
# (114506, 24)

# %%
acquisitions = pd.read_excel('crunchbase_monthly_export_d43b4klo2ade53.xlsx', sheet_name='Acquisitions')
# Out:
# /Users/yael/anaconda3/lib/python3.11/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
acquisitions.head()
# Out:
#                  company_permalink    company_name  \
# 0            /organization/waywire        #waywire
# 1      /organization/fluff-friends  (fluff)Friends
# 2                /organization/red           (RED)
# 3  /organization/vandaele-holdings               .
# 4        /organization/co-internet             .CO
#
#                         company_category_list company_market  \
# 0  |Entertainment|Politics|Social Media|News|           News
# 1                                         NaN            NaN
# 2                                |Nonprofits|     Nonprofits
# 3                                         NaN            NaN
# 4            |Registrars|Domains|Curated Web|     Registrars
#
#   company_country_code company_state_code company_region company_city  \
# 0                  USA                 NY  New York City     New York
# 1                  NaN                NaN            NaN          NaN
# 2                  USA                 NY  New York City     New York
# ...

# %%
acquisitions.shape
# Out:
# (13070, 22)

# %%
startups = pd.read_csv('startups.csv')

# %%
startups.head()
# Out:
#                     name     city  \
# 0          Campus Bubble  Atlanta
# 1               DueProps  Atlanta
# 2              SalesLoft  Atlanta
# 3  The Coca-Cola Company  Atlanta
# 4              EarthLink  Atlanta
#
#                                              tagline  \
# 0                             Your Academic Identity
# 1  Gamifying the $46 Billion Employee Incentives ...
# 2          Quickly build high-quality prospect lists
# 3                                                NaN
# 4                                                NaN
#
#                                          description
# 0  Campus Bubble (“CB”) is the Academic Community...
# 1                                t unprecedented ...
# 2                build high-quality prospect lists\n
# 3  Coca-Cola Journey is a digital magazine that f...
# 4                                                NaN

# %%
startups.join(companies.set_index('company_name'), on='name')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/7x/y3pstmxx73nglmqj36qhzblh0000gn/T/ipykernel_39074/4023285522.py in ?()
# ----> 1 startups.join(companies.set_index('company_name'), on='name')
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5855                     if not found:
#    5856                         missing.append(col)
#    5857
#    5858         if missing:
# -> 5859             raise KeyError(f"None of {missing} are in the columns")
#    5860
#    5861         if inplace:
#    5862             frame = self
#
# KeyError: "None of ['company_name'] are in the columns"

# %%
test = pd.DataFrame({'company_name': ['DueProps', 'SalesLoft', 'EarthLink'],
                      'category': ['B0', 'B1', 'B2']})

# %%
test
# Out:
#   company_name category
# 0     DueProps       B0
# 1    SalesLoft       B1
# 2    EarthLink       B2

# %%
startups.join(test.set_index('company_name'), on='name')
# Out:
#                                  name           city  \
# 0                       Campus Bubble        Atlanta
# 1                            DueProps        Atlanta
# 2                           SalesLoft        Atlanta
# 3               The Coca-Cola Company        Atlanta
# 4                           EarthLink        Atlanta
# ...                               ...            ...
# 42033  Venture Philanthrophy Partners  Washington DC
# 42034             The Shopping Asylum  Washington DC
# 42035                 UP Technologies  Washington DC
# 42036      Galaxie restaurant and bar  Washington DC
# 42037                  Avenger Mobile  Washington DC
#
#                                                  tagline  \
# 0                                 Your Academic Identity
# 1      Gamifying the $46 Billion Employee Incentives ...
# 2              Quickly build high-quality prospect lists
# 3                                                    NaN
# ...

# %%
c2 = pd.read_csv('companies.csv',sep=';')

# %%
c2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63215 entries, 0 to 63214
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               63214 non-null  object
#  1   homepage_url       59069 non-null  object
#  2   category_list      63215 non-null  object
#  3   funding_total_usd  63215 non-null  object
#  4   status             63215 non-null  object
#  5   country_code       57799 non-null  object
#  6   state_code         56263 non-null  object
#  7   region             56760 non-null  object
#  8   city               56762 non-null  object
#  9   funding_rounds     63215 non-null  int64
#  10  founded_at         49707 non-null  object
#  11  first_funding_at   63192 non-null  object
#  12  last_funding_at    63215 non-null  object
#  13  permalink          63215 non-null  object
# dtypes: int64(1), object(13)
# memory usage: 6.8+ MB

# %%
c2.head()
# Out:
#                      Name                       homepage_url  \
# 0                   #fame                 http://livfame.com
# 1                :Qounter             http://www.qounter.com
# 2  (THE) ONE of THEM,Inc.                http://oneofthem.jp
# 3                 0-6.com                 http://www.0-6.com
# 4        004 Technologies  http://004gmbh.de/en/004-interact
#
#                                        category_list funding_total_usd  \
# 0                                              Media          10000000
# 1  Application Platforms|Real Time|Social Network...            700000
# 2                                  Apps|Games|Mobile           3406878
# 3                                        Curated Web           2000000
# 4                                           Software                 -
#
#       status country_code state_code                 region           city  \
# 0  operating          IND         16                 Mumbai         Mumbai
# ...

# %%
c3 = pd.read_csv('startups.csv')

# %%
c3.head()
# Out:
#                     name     city  \
# 0          Campus Bubble  Atlanta
# 1               DueProps  Atlanta
# 2              SalesLoft  Atlanta
# 3  The Coca-Cola Company  Atlanta
# 4              EarthLink  Atlanta
#
#                                              tagline  \
# 0                             Your Academic Identity
# 1  Gamifying the $46 Billion Employee Incentives ...
# 2          Quickly build high-quality prospect lists
# 3                                                NaN
# 4                                                NaN
#
#                                          description
# 0  Campus Bubble (“CB”) is the Academic Community...
# 1                                t unprecedented ...
# 2                build high-quality prospect lists\n
# 3  Coca-Cola Journey is a digital magazine that f...
# 4                                                NaN

# %%
startups_join = c3.join(c2.set_index('Name'), on='name', how='inner', lsuffix='_startups', rsuffix='_kaggle')

# %%
startups_join.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9261 entries, 0 to 42023
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               9257 non-null   object
#  1   city_startups      9261 non-null   object
#  2   tagline            7127 non-null   object
#  3   description        7424 non-null   object
#  4   homepage_url       9161 non-null   object
#  5   category_list      9261 non-null   object
#  6   funding_total_usd  9261 non-null   object
#  7   status             9261 non-null   object
#  8   country_code       8743 non-null   object
#  9   state_code         8532 non-null   object
#  10  region             8676 non-null   object
#  11  city_kaggle        8676 non-null   object
#  12  funding_rounds     9261 non-null   int64
#  13  founded_at         8292 non-null   object
#  14  first_funding_at   9254 non-null   object
#  15  last_funding_at    9261 non-null   object
# ...

# %%
startups_join = startups_join.reset_index(drop=True)

# %%
startups_join.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9261 entries, 0 to 9260
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               9257 non-null   object
#  1   city_startups      9261 non-null   object
#  2   tagline            7127 non-null   object
#  3   description        7424 non-null   object
#  4   homepage_url       9161 non-null   object
#  5   category_list      9261 non-null   object
#  6   funding_total_usd  9261 non-null   object
#  7   status             9261 non-null   object
#  8   country_code       8743 non-null   object
#  9   state_code         8532 non-null   object
#  10  region             8676 non-null   object
#  11  city_kaggle        8676 non-null   object
#  12  funding_rounds     9261 non-null   int64
#  13  founded_at         8292 non-null   object
#  14  first_funding_at   9254 non-null   object
#  15  last_funding_at    9261 non-null   object
# ...

# %%
startups_join.to_csv('startups_join.csv')

# %%
import json

# %%
f = open('SBA_Public.json')
json.load(f)
# Out:
# {'conformsTo': 'https://project-open-data.cio.gov/v1.1/schema',
#  'describedBy': 'https://project-open-data.cio.gov/v1.1/schema/catalog.json',
#  '@context': 'https://project-open-data.cio.gov/v1.1/schema/catalog.jsonld',
#  '@type': 'dcat:Catalog',
#  'dataset': [{'@type': 'dcat:Dataset',
#    'title': 'Bureau IT Leadership Directory',
#    'description': 'A directory of all SBA officials with the title of CIO or duties of a CIO.',
#    'modified': '2023-01-11T16:38:28.823Z',
#    'accessLevel': 'public',
#    'identifier': 'SBA-OCIO-2015-08-001',
#    'landingPage': 'https://www.sba.gov/about-sba/open-government/digital-sba',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'rights': 'true',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'Small Business Administration'},
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Melvin Brown',
#     'hasEmail': 'mailto:melvin.brown@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
# ...
