# %%
import numpy as np
import pandas as pd
import requests

# %%
# loading first data set which contains company names and descriptions
startups = pd.read_csv('startups.csv')

# %%
startups.head()
# Out:
#                     name     city  \
# 0          Campus Bubble  Atlanta
# 1               DueProps  Atlanta
# 2              SalesLoft  Atlanta
# 3  The Coca-Cola Company  Atlanta
# 4              EarthLink  Atlanta
#
#                                              tagline  \
# 0                             Your Academic Identity
# 1  Gamifying the $46 Billion Employee Incentives ...
# 2          Quickly build high-quality prospect lists
# 3                                                NaN
# 4                                                NaN
#
#                                          description
# 0  Campus Bubble (“CB”) is the Academic Community...
# 1                                t unprecedented ...
# 2                build high-quality prospect lists\n
# 3  Coca-Cola Journey is a digital magazine that f...
# 4                                                NaN

# %%
startups.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42038 entries, 0 to 42037
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         42034 non-null  object
#  1   city         42038 non-null  object
#  2   tagline      36730 non-null  object
#  3   description  37174 non-null  object
# dtypes: object(4)
# memory usage: 1.3+ MB

# %%
startups.isna().sum()
# Out:
# name              4
# city              0
# tagline        5308
# description    4864
# dtype: int64

# %%
# I need to strip the name columns of all spaces or extra characters and make them lower case, so that the join can get the most possible matches

startups['name_unformatted'] = startups['name']

# %%
for i in range(len(startups['name_unformatted'])):
    startups['name_unformatted'][i] = str(startups['name_unformatted'][i]).lower().replace(' ', '')
    if not startups['name_unformatted'][i].isalnum():
        for char in startups['name_unformatted'][i]:
            if not char.isalnum():
                startups['name_unformatted'][i] = startups['name_unformatted'][i].replace(char, '')

# %%
startups.head()
# Out:
#                     name     city  \
# 0          Campus Bubble  Atlanta
# 1               DueProps  Atlanta
# 2              SalesLoft  Atlanta
# 3  The Coca-Cola Company  Atlanta
# 4              EarthLink  Atlanta
#
#                                              tagline  \
# 0                             Your Academic Identity
# 1  Gamifying the $46 Billion Employee Incentives ...
# 2          Quickly build high-quality prospect lists
# 3                                                NaN
# 4                                                NaN
#
#                                          description    name_unformatted
# 0  Campus Bubble (“CB”) is the Academic Community...        campusbubble
# 1                                t unprecedented ...            dueprops
# 2                build high-quality prospect lists\n           salesloft
# 3  Coca-Cola Journey is a digital magazine that f...  thecocacolacompany
# 4                                                NaN           earthlink

# %%
# loading the second dataset which contains more information on the companies such as categories, status, funding, and URLs
companies = pd.read_csv('companies.csv',sep=';')

# %%
companies.head()
# Out:
#                      Name                       homepage_url  \
# 0                   #fame                 http://livfame.com
# 1                :Qounter             http://www.qounter.com
# 2  (THE) ONE of THEM,Inc.                http://oneofthem.jp
# 3                 0-6.com                 http://www.0-6.com
# 4        004 Technologies  http://004gmbh.de/en/004-interact
#
#                                        category_list funding_total_usd  \
# 0                                              Media          10000000
# 1  Application Platforms|Real Time|Social Network...            700000
# 2                                  Apps|Games|Mobile           3406878
# 3                                        Curated Web           2000000
# 4                                           Software                 -
#
#       status country_code state_code                 region           city  \
# 0  operating          IND         16                 Mumbai         Mumbai
# 1  operating          USA         DE             DE - Other  Delaware City
# 2  operating          NaN        NaN                    NaN            NaN
# 3  operating          CHN         22                Beijing        Beijing
# 4  operating          USA         IL  Springfield, Illinois      Champaign
#
#    funding_rounds  founded_at first_funding_at last_funding_at  \
# 0               1         NaN       05/01/2015      05/01/2015
# 1               2  04/09/2014       01/03/2014      14/10/2014
# 2               1         NaN       30/01/2014      30/01/2014
# 3               1  01/01/2007       19/03/2008      19/03/2008
# 4               1  01/01/2010       24/07/2014      24/07/2014
#
#                              permalink
# 0                  /organization/-fame
# 1               /organization/-qounter
# 2  /organization/-the-one-of-them-inc-
# 3                /organization/0-6-com
# 4       /organization/004-technologies

# %%
companies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63215 entries, 0 to 63214
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               63214 non-null  object
#  1   homepage_url       59069 non-null  object
#  2   category_list      63215 non-null  object
#  3   funding_total_usd  63215 non-null  object
#  4   status             63215 non-null  object
#  5   country_code       57799 non-null  object
#  6   state_code         56263 non-null  object
#  7   region             56760 non-null  object
#  8   city               56762 non-null  object
#  9   funding_rounds     63215 non-null  int64
#  10  founded_at         49707 non-null  object
#  11  first_funding_at   63192 non-null  object
#  12  last_funding_at    63215 non-null  object
#  13  permalink          63215 non-null  object
# dtypes: int64(1), object(13)
# memory usage: 6.8+ MB

# %%
# creating an unformatted name column here as well to maximize the join
companies['name_unformatted'] = companies['Name']

# %%
for i in range(len(companies['name_unformatted'])):
    companies['name_unformatted'][i] = str(companies['name_unformatted'][i]).lower().replace(' ', '')
    if not companies['name_unformatted'][i].isalnum():
        for char in companies['name_unformatted'][i]:
            if not char.isalnum():
                companies['name_unformatted'][i] = companies['name_unformatted'][i].replace(char, '')
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
# trying to determine status of companies now by testing website URLs 

#companies['current_status'] = companies['status']
#for i in range(len(companies['homepage_url'])):
#    if requests.get(companies['homepage_url'][i]).status_code == 200:
#        companies['current_status'][i] = 'operating'
#    else:
#        companies['current_status'][i] = 'closed' 
        
# r.content.decode('utf-8')

# %%
startups_join = startups.join(companies.set_index('name_unformatted'), on='name_unformatted', how='inner', lsuffix='_startups-list', rsuffix='_crunchbase')

# %%
startups_join.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10622 entries, 0 to 42023
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   name                10618 non-null  object
#  1   city_startups-list  10622 non-null  object
#  2   tagline             8200 non-null   object
#  3   description         8531 non-null   object
#  4   name_unformatted    10622 non-null  object
#  5   Name                10618 non-null  object
#  6   homepage_url        10495 non-null  object
#  7   category_list       10622 non-null  object
#  8   funding_total_usd   10622 non-null  object
#  9   status              10622 non-null  object
#  10  country_code        9997 non-null   object
#  11  state_code          9741 non-null   object
#  12  region              9911 non-null   object
#  13  city_crunchbase     9911 non-null   object
#  14  funding_rounds      10622 non-null  int64
#  15  founded_at          9483 non-null   object
#  16  first_funding_at    10615 non-null  object
#  17  last_funding_at     10622 non-null  object
#  18  permalink           10622 non-null  object
# dtypes: int64(1), object(18)
# memory usage: 1.6+ MB

# %%
startups_join.head()
# Out:
#             name city_startups-list  \
# 0  Campus Bubble            Atlanta
# 1       DueProps            Atlanta
# 2      SalesLoft            Atlanta
# 4      EarthLink            Atlanta
# 5        REscour            Atlanta
#
#                                              tagline  \
# 0                             Your Academic Identity
# 1  Gamifying the $46 Billion Employee Incentives ...
# 2          Quickly build high-quality prospect lists
# 4                                                NaN
# 5  Market intelligence and analytics for commerci...
#
#                                          description name_unformatted  \
# 0  Campus Bubble (“CB”) is the Academic Community...     campusbubble
# 1                                t unprecedented ...         dueprops
# 2                build high-quality prospect lists\n        salesloft
# 4                                                NaN        earthlink
# 5  REscour is a data platform and decision engine...          rescour
#
#             Name                  homepage_url  \
# 0  Campus Bubble  http://www.campusbubble.com/
# 1       DueProps           http://dueprops.com
# 2      SalesLoft          http://salesloft.com
# 4      EarthLink      http://www.earthlink.net
# 5        REscour        http://www.rescour.com
#
#                                        category_list funding_total_usd  \
# 0  Colleges|Education|Networking|SaaS|Social Medi...            525000
# 1                                              Games            200000
# 2  B2B|Lead Generation|SaaS|Sales and Marketing|S...          11218000
# 4                               Curated Web|Software          23598258
# 5                 Commercial Real Estate|Real Estate           2800000
#
#       status country_code state_code   region city_crunchbase  funding_rounds  \
# 0  operating          NaN        NaN      NaN             NaN               1
# 1  operating          USA         GA  Atlanta         Atlanta               1
# 2  operating          USA         GA  Atlanta         Atlanta               4
# 4        ipo          USA         GA  Atlanta         Atlanta               1
# 5  operating          USA         GA  Atlanta         Atlanta               2
#
#    founded_at first_funding_at last_funding_at                    permalink
# 0  01/03/2012       04/06/2014      04/06/2014  /organization/campus-bubble
# 1  23/05/2011       01/11/2011      01/11/2011       /organization/dueprops
# 2  01/10/2011       17/05/2012      01/04/2015      /organization/salesloft
# 4  01/01/1994       12/04/2011      12/04/2011      /organization/earthlink
# 5  01/01/2013       04/03/2015      03/12/2015        /organization/rescour

# %%
startups_join = startups_join.reset_index(drop=True)

# %%
startups_join.head()
# Out:
#             name city_startups-list  \
# 0  Campus Bubble            Atlanta
# 1       DueProps            Atlanta
# 2      SalesLoft            Atlanta
# 3      EarthLink            Atlanta
# 4        REscour            Atlanta
#
#                                              tagline  \
# 0                             Your Academic Identity
# 1  Gamifying the $46 Billion Employee Incentives ...
# 2          Quickly build high-quality prospect lists
# 3                                                NaN
# 4  Market intelligence and analytics for commerci...
#
#                                          description name_unformatted  \
# 0  Campus Bubble (“CB”) is the Academic Community...     campusbubble
# 1                                t unprecedented ...         dueprops
# 2                build high-quality prospect lists\n        salesloft
# 3                                                NaN        earthlink
# 4  REscour is a data platform and decision engine...          rescour
#
#             Name                  homepage_url  \
# 0  Campus Bubble  http://www.campusbubble.com/
# 1       DueProps           http://dueprops.com
# 2      SalesLoft          http://salesloft.com
# 3      EarthLink      http://www.earthlink.net
# 4        REscour        http://www.rescour.com
#
#                                        category_list funding_total_usd  \
# 0  Colleges|Education|Networking|SaaS|Social Medi...            525000
# 1                                              Games            200000
# 2  B2B|Lead Generation|SaaS|Sales and Marketing|S...          11218000
# 3                               Curated Web|Software          23598258
# 4                 Commercial Real Estate|Real Estate           2800000
#
#       status country_code state_code   region city_crunchbase  funding_rounds  \
# 0  operating          NaN        NaN      NaN             NaN               1
# 1  operating          USA         GA  Atlanta         Atlanta               1
# 2  operating          USA         GA  Atlanta         Atlanta               4
# 3        ipo          USA         GA  Atlanta         Atlanta               1
# 4  operating          USA         GA  Atlanta         Atlanta               2
#
#    founded_at first_funding_at last_funding_at                    permalink
# 0  01/03/2012       04/06/2014      04/06/2014  /organization/campus-bubble
# 1  23/05/2011       01/11/2011      01/11/2011       /organization/dueprops
# 2  01/10/2011       17/05/2012      01/04/2015      /organization/salesloft
# 3  01/01/1994       12/04/2011      12/04/2011      /organization/earthlink
# 4  01/01/2013       04/03/2015      03/12/2015        /organization/rescour

# %%
startups_join.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10622 entries, 0 to 10621
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   name                10618 non-null  object
#  1   city_startups-list  10622 non-null  object
#  2   tagline             8200 non-null   object
#  3   description         8531 non-null   object
#  4   name_unformatted    10622 non-null  object
#  5   Name                10618 non-null  object
#  6   homepage_url        10495 non-null  object
#  7   category_list       10622 non-null  object
#  8   funding_total_usd   10622 non-null  object
#  9   status              10622 non-null  object
#  10  country_code        9997 non-null   object
#  11  state_code          9741 non-null   object
#  12  region              9911 non-null   object
#  13  city_crunchbase     9911 non-null   object
#  14  funding_rounds      10622 non-null  int64
#  15  founded_at          9483 non-null   object
#  16  first_funding_at    10615 non-null  object
#  17  last_funding_at     10622 non-null  object
#  18  permalink           10622 non-null  object
# dtypes: int64(1), object(18)
# memory usage: 1.5+ MB

# %%
# ran this to get csv to work with
# startups_join.to_csv('startups_join.csv')

# %%
startups_join.isna().sum()
# Out:
# name                     4
# city_startups-list       0
# tagline               2422
# description           2091
# name_unformatted         0
# Name                     4
# homepage_url           127
# category_list            0
# funding_total_usd        0
# status                   0
# country_code           625
# state_code             881
# region                 711
# city_crunchbase        711
# funding_rounds           0
# founded_at            1139
# first_funding_at         7
# last_funding_at          0
# permalink                0
# dtype: int64

# %%
copy = startups_join

# %%
copy.shape
# Out:
# (10622, 19)

# %%
# if I drop all nulls I lose 4118 rows
copy.dropna().shape
# Out:
# (6504, 19)

# %%
# which rows don't have names?
copy[copy['name'].isna()]
# Out:
#      name city_startups-list               tagline            description  \
# 1719  NaN             Boston                   NaN                     NA
# 1720  NaN          Hong Kong  Consumer Electronics  Consumer electronics.
# 1721  NaN           Tel Aviv                   NaN                 mpaign
# 1722  NaN      Washington DC                   NaN                    NaN
#
#      name_unformatted Name           homepage_url category_list  \
# 1719              nan  NaN  http://tellitin10.com      Startups
# 1720              nan  NaN  http://tellitin10.com      Startups
# 1721              nan  NaN  http://tellitin10.com      Startups
# 1722              nan  NaN  http://tellitin10.com      Startups
#
#      funding_total_usd  status country_code state_code            region  \
# 1719             25000  closed          USA         OR  Portland, Oregon
# 1720             25000  closed          USA         OR  Portland, Oregon
# 1721             25000  closed          USA         OR  Portland, Oregon
# 1722             25000  closed          USA         OR  Portland, Oregon
#
#      city_crunchbase  funding_rounds  founded_at first_funding_at  \
# 1719        Portland               1  01/10/2011       01/03/2012
# 1720        Portland               1  01/10/2011       01/03/2012
# 1721        Portland               1  01/10/2011       01/03/2012
# 1722        Portland               1  01/10/2011       01/03/2012
#
#      last_funding_at                 permalink
# 1719      01/03/2012  /organization/tell-it-in
# 1720      01/03/2012  /organization/tell-it-in
# 1721      01/03/2012  /organization/tell-it-in
# 1722      01/03/2012  /organization/tell-it-in

# %%
# all these companies have the same URL and permalink, making sure there aren't others
copy[copy['homepage_url']=='http://tellitin10.com']
# Out:
#      name city_startups-list               tagline            description  \
# 1719  NaN             Boston                   NaN                     NA
# 1720  NaN          Hong Kong  Consumer Electronics  Consumer electronics.
# 1721  NaN           Tel Aviv                   NaN                 mpaign
# 1722  NaN      Washington DC                   NaN                    NaN
#
#      name_unformatted Name           homepage_url category_list  \
# 1719              nan  NaN  http://tellitin10.com      Startups
# 1720              nan  NaN  http://tellitin10.com      Startups
# 1721              nan  NaN  http://tellitin10.com      Startups
# 1722              nan  NaN  http://tellitin10.com      Startups
#
#      funding_total_usd  status country_code state_code            region  \
# 1719             25000  closed          USA         OR  Portland, Oregon
# 1720             25000  closed          USA         OR  Portland, Oregon
# 1721             25000  closed          USA         OR  Portland, Oregon
# 1722             25000  closed          USA         OR  Portland, Oregon
#
#      city_crunchbase  funding_rounds  founded_at first_funding_at  \
# 1719        Portland               1  01/10/2011       01/03/2012
# 1720        Portland               1  01/10/2011       01/03/2012
# 1721        Portland               1  01/10/2011       01/03/2012
# 1722        Portland               1  01/10/2011       01/03/2012
#
#      last_funding_at                 permalink
# 1719      01/03/2012  /organization/tell-it-in
# 1720      01/03/2012  /organization/tell-it-in
# 1721      01/03/2012  /organization/tell-it-in
# 1722      01/03/2012  /organization/tell-it-in

# %%
# just drop these
copy = copy.dropna(subset='name')

# %%
# checking that 4 rows are gone
copy.shape
# Out:
# (10618, 19)

# %%
# do the tagline and description null columns coincide?
copy.dropna(subset='tagline').shape # 8200 rows left
copy.dropna(subset=['tagline', 'description']).shape # 8010 rows left, an extra 190, so they largely do coincide
# Out:
# (8009, 19)

# %%
# I'll drop all the rows that are missing descriptions since that's the crux of my project
copy = copy.dropna(subset='description')

# %%
copy.shape
# Out:
# (8528, 19)

# %%
# I can safely drop city_crunchbase and Name columns since the city_startups-list and name columns have all that information anyway
# I also don't need name_unformatted or permalink
# I don't think I need the state_code and region columns either if I have city and country
copy = copy.drop(columns=['name_unformatted', 'Name', 'city_crunchbase', 'state_code', 'region', 'permalink'], axis=1)

# %%
# checking that columns were dropped
copy.shape
# Out:
# (8528, 13)

# %%
# I should be able to impute country code from the city column
copy[['']]

# %%
# which rows don't have URLs?
copy[copy['homepage_url'].isna()]
# some of these seem to still be operating and have websites, should try to find them and add them in
# Out:
#                            name city_startups-list  \
# 287                  Kin Valley             Austin
# 299                      Kambit             Austin
# 542                        Noow             Austin
# 695                     Twiddly          Bangalore
# 727                       Torch          Bangalore
# ...                         ...                ...
# 10267                 TasteAway            Toronto
# 10530  Cotton & Reed Distillery      Washington DC
# 10535                   YoBucko      Washington DC
# 10585                    KickUp      Washington DC
# 10599                     Zest       Washington DC
#
#                                                  tagline  \
# 287                                Connect With Your Kin
# 299                Changing the Way People Create Change
# 542                 Physical therapy engagement platform
# 695    Personalised content browser on the Android lo...
# 727               Google Analytics for Offline Retailers
# ...                                                  ...
# 10267  You Crave, We deliver. Online food takeout and...
# 10530  Craft Distillery - exerpimental spirits, forag...
# 10535  YoBucko is an online personal finance guide fo...
# 10585  KickUp creates peer-to-peer engagement systems...
# 10599               empowering food bloggers everywhere
#
#                                              description homepage_url  \
# 287    The way people connect online has become trivi...          NaN
# 299    ides a platform that combines two incredible f...          NaN
# 542    s, the system reminds them to do their workout...          NaN
# 695    f the 5 startups which are in the current batc...          NaN
# 727    Torch provides location analytics, customer en...          NaN
# ...                                                  ...          ...
# 10267  s in adding a technology layer on a fragmented...          NaN
# 10530  Cotton & Reed delivers experimental and natura...          NaN
# 10535  YoBucko is a personal finance site for Generat...          NaN
# 10585  one reason teachers leave or move from the cla...          NaN
# 10599                                      (In progress)          NaN
#
#                                            category_list funding_total_usd  \
# 287                                         Social Media                 -
# 299                                             Software                 -
# 542                                          Health Care                 -
# 695             Content Discovery|Mobile|Personalization             30000
# 727                       Monetization|Service Providers             30000
# ...                                                  ...               ...
# 10267                    Delivery|E-Commerce|Restaurants            450000
# 10530              Restaurants|Services|Wine And Spirits                 -
# 10535  Education|Financial Services|Lead Generation|P...            125125
# 10585                Collaboration|Communities|Education            100000
# 10599  Blogging Platforms|Monetization|Social Media|S...             25000
#
#           status country_code  funding_rounds  founded_at first_funding_at  \
# 287    operating          USA               1  01/01/2009       20/12/2012
# 299       closed          USA               2  22/09/2011       28/02/2012
# 542    operating          NaN               1         NaN       20/12/2013
# 695    operating          NaN               1         NaN       28/10/2014
# 727    operating          NaN               1         NaN       28/10/2014
# ...          ...          ...             ...         ...              ...
# 10267  operating          CAN               2  15/12/2012       30/05/2013
# 10530  operating          USA               1  01/03/2013       22/10/2013
# 10535  operating          USA               1         NaN       20/06/2011
# 10585     closed          NaN               1         NaN       17/06/2015
# 10599  operating          USA               1         NaN       01/12/2014
#
#       last_funding_at
# 287        20/12/2012
# 299        15/08/2012
# 542        20/12/2013
# 695        28/10/2014
# 727        28/10/2014
# ...               ...
# 10267      30/06/2014
# 10530      22/10/2013
# 10535      20/06/2011
# 10585      17/06/2015
# 10599      01/12/2014
#
# [100 rows x 13 columns]

# %%
# for these I can at least impute from first_funding_at, I should see if those seem to correlate
copy[copy['founded_at'].isna()]
# Out:
#             name city_startups-list  \
# 27      Verdeeco            Atlanta
# 33      Calendly            Atlanta
# 48       i-nexus            Atlanta
# 68          abeo            Atlanta
# 71       Sevamob            Atlanta
# ...          ...                ...
# 10583  Workhorse      Washington DC
# 10585     KickUp      Washington DC
# 10593     Engage      Washington DC
# 10599      Zest       Washington DC
# 10617       Tapp      Washington DC
#
#                                                  tagline  \
# 27         Energy Data Analytics & Applications Platform
# 33                          Simple, beautiful scheduling
# 48              Business Execution Software as a Service
# 68            eHarmony/Linkedin/ for employee engagement
# 71     Convenient access to primary healthcare in dev...
# ...                                                  ...
# 10583                   No bullshit strategy and design.
# 10585  KickUp creates peer-to-peer engagement systems...
# 10593  A digital agency with a passion for disrupting...
# 10599               empowering food bloggers everywhere
# 10617                                  Did you tap that?
#
#                                              description  \
# 27     The deployment of smart devices across the nat...
# 33     endly, it can take up to 7 emails over 2-3 day...
# 48     ecution software helps large organisations ali...
# 68     ou create a private social network for your or...
# 71     lth via online health exchange for internet-sa...
# ...                                                  ...
# 10583  We're a full-service design studio in Washingt...
# 10585  one reason teachers leave or move from the cla...
# 10593  We give brands, candidates, and causes a voice...
# 10599                                      (In progress)
# 10617    Imagine, being able to place your phone on o...
#
#                      homepage_url  \
# 27        http://www.verdeeco.com
# 33            http://calendly.com
# 48         http://www.i-nexus.com
# 68                http://abeo.com
# 71            http://sevamob.com/
# ...                           ...
# 10583  http://www.workhorse.co.in
# 10585                         NaN
# 10593       http://www.engage.com
# 10599                         NaN
# 10617           http://tapptv.com
#
#                                            category_list funding_total_usd  \
# 27                                             Analytics           1514205
# 33                                              Software                 -
# 48        Business Services|Software|Software Compliance           6000000
# 68                                           Health Care           2012700
# 71                                           Health Care                 -
# ...                                                  ...               ...
# 10583                                           Internet                 -
# 10585                Collaboration|Communities|Education            100000
# 10593  Match-Making|Online Dating|Private Social Netw...           5000000
# 10599  Blogging Platforms|Monetization|Social Media|S...             25000
# 10617                                        Photography                 -
#
#           status country_code  funding_rounds founded_at first_funding_at  \
# 27      acquired          USA               2        NaN       14/07/2011
# 33     operating          USA               1        NaN       25/04/2014
# 48     operating          GBR               2        NaN       30/06/2008
# 68     operating          USA               1        NaN       30/11/2011
# 71     operating          USA               1        NaN       28/09/2012
# ...          ...          ...             ...        ...              ...
# 10583  operating          IND               1        NaN       12/05/2015
# 10585     closed          NaN               1        NaN       17/06/2015
# 10593     closed          USA               1        NaN       12/07/2006
# 10599  operating          USA               1        NaN       01/12/2014
# 10617  operating          NaN               1        NaN       12/03/2014
#
#       last_funding_at
# 27         28/11/2012
# 33         25/04/2014
# 48         25/07/2008
# 68         30/11/2011
# 71         28/09/2012
# ...               ...
# 10583      12/05/2015
# 10585      17/06/2015
# 10593      12/07/2006
# 10599      01/12/2014
# 10617      12/03/2014
#
# [875 rows x 13 columns]

# %%
copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8528 entries, 0 to 10620
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   name                8528 non-null   object
#  1   city_startups-list  8528 non-null   object
#  2   tagline             8009 non-null   object
#  3   description         8528 non-null   object
#  4   homepage_url        8428 non-null   object
#  5   category_list       8528 non-null   object
#  6   funding_total_usd   8528 non-null   object
#  7   status              8528 non-null   object
#  8   country_code        7976 non-null   object
#  9   funding_rounds      8528 non-null   int64
#  10  founded_at          7653 non-null   object
#  11  first_funding_at    8521 non-null   object
#  12  last_funding_at     8528 non-null   object
# dtypes: int64(1), object(12)
# memory usage: 932.8+ KB

# %%
# I can impute most of these from founded at, with the
copy[copy['first_funding_at'].isna()]
# Out:
#                name city_startups-list  \
# 238     RealMassive             Austin
# 3047  MotionMetrics             London
# 3379          dopay             London
# 6171     Keymetrics           New York
# 8449     Topicmarks      San Francisco
# 9151         Sontra          Sao Paulo
# 9848        Aniways           Tel Aviv
#
#                                                 tagline  \
# 238   Open data, marketing platform for commercial r...
# 3047                      Wearables for ski instruction
# 3379                               Banking the unbanked
# 6171  Comprehensive monitoring & management software...
# 8449    Auto-organize your cloud documents meaningfully
# 9151   Uber for Trucks. re-inventing trucking in Brazil
# 9848            Contextualized. personalized. monetized
#
#                                             description  \
# 238   ry: Zillow for commercial real estate, monetiz...
# 3047  We create hardware and software to help you im...
# 3379  a cloud-based payroll service that allows empl...
# 6171  e is positioned as a paid extension of our exi...
# 8449  Topicmarks has launched in beta a web service ...
# 9151  born as a web and mobile based marketplace wit...
# 9848  Aniways has an SDK for adding "intelligence an...
#
#                     homepage_url  \
# 238   http://www.realmassive.com
# 3047     http://motionmetrics.co
# 3379        http://www.dopay.com
# 6171      https://keymetrics.io/
# 8449       http://topicmarks.com
# 9151    http://www.sontra.com.br
# 9848      http://www.aniways.com
#
#                                           category_list funding_total_usd  \
# 238   Commercial Real Estate|Marketing Automation|Ma...           8000000
# 3047                      Hardware + Software|Wearables            150000
# 3379                                 Financial Services  1675550.80940274
# 6171                                               SaaS            360000
# 8449  Curated Web|Education|Knowledge Management|Nat...            150000
# 9151          Customer Service|Logistics|Transportation           4349586
# 9848     Advertising|Chat|Messaging|Mobile|Social Media           1190000
#
#          status country_code  funding_rounds  founded_at first_funding_at  \
# 238   operating          USA               2  11/02/2013              NaN
# 3047     closed          GBR               2  24/09/2013              NaN
# 3379  operating          GBR               3  04/01/2014              NaN
# 6171  operating          USA               3         NaN              NaN
# 8449   acquired          USA               2  01/01/2009              NaN
# 9151  operating          BRA               5  01/01/2013              NaN
# 9848  operating          ISR               6  01/01/2012              NaN
#
#      last_funding_at
# 238       14/05/2015
# 3047      01/09/2014
# 3379      01/09/2014
# 6171      01/10/2015
# 8449      18/03/2011
# 9151      23/01/2015
# 9848      23/03/2014

# %%
# a lot of funding_total_usd rows don't register as null because they have a '-' character
# 1464 rows total (before dropping any nulls)
copy[copy['funding_total_usd'] == '-']
# Out:
#                      name city_startups-list  \
# 5                viaCycle            Atlanta
# 8                    MOVL            Atlanta
# 26           SportsCrunch            Atlanta
# 29               Storyful            Atlanta
# 33               Calendly            Atlanta
# ...                   ...                ...
# 10577       Freedom Farms      Washington DC
# 10583           Workhorse      Washington DC
# 10592           Encounter      Washington DC
# 10616  Fit Body Club, Co.      Washington DC
# 10617                Tapp      Washington DC
#
#                                                  tagline  \
# 5      Zipcar for bicycles. Call or text, unlock, and...
# 8                 Connecting Mobile Devices and SmartTVs
# 26                                 LinkedIn for Sports.
# 29          The 1st news agency for the social media age
# 33                          Simple, beautiful scheduling
# ...                                                  ...
# 10577               Growing Prosperity. Feeding Progress
# 10583                   No bullshit strategy and design.
# 10592            Qlik View for medical supply management
# 10616  A step above Equinox - we sell results, not ac...
# 10617                                  Did you tap that?
#
#                                              description name_unformatted  \
# 5      viaCycle creates bicycle sharing technology th...         viacycle
# 8      The MOVL Connect Platform and KontrolTV provid...             movl
# 26                                      SportsCrunch.com     sportscrunch
# 29     Storyful solves the biggest problem facing the...         storyful
# 33     endly, it can take up to 7 emails over 2-3 day...         calendly
# ...                                                  ...              ...
# 10577  Aquaponics. This is about a new way. This is a...     freedomfarms
# 10583  We're a full-service design studio in Washingt...        workhorse
# 10592  ic health record (EHR) software integration us...        encounter
# 10616  Fit Body Club is a results-oriented fitness co...    fitbodyclubco
# 10617    Imagine, being able to place your phone on o...             tapp
#
#                      Name                    homepage_url  \
# 5                viaCycle         http://www.viacycle.com
# 8                    MOVL               http://kontrol.tv
# 26           SportsCrunch     http://www.SportsCrunch.com
# 29               Storyful             http://storyful.com
# 33               Calendly             http://calendly.com
# ...                   ...                             ...
# 10577       Freedom Farms  http://www.freedomfarmsdc.com/
# 10583           Workhorse      http://www.workhorse.co.in
# 10592           Encounter         http://tryencounter.com
# 10616  Fit Body Club, Co.       http://www.fitbodyclub.co
# 10617                TAPP               http://tapptv.com
#
#                                            category_list funding_total_usd  \
# 5      Hardware + Software|Mobile|Mobility|Transporta...                 -
# 8      Android|Apps|iOS|Social Network Media|Software...                 -
# 26                                 Consumer Goods|Sports                 -
# 29                    Media|News|Publishing|Social Media                 -
# 33                                              Software                 -
# ...                                                  ...               ...
# 10577                                        Hospitality                 -
# 10583                                           Internet                 -
# 10592             Apps|Mobile|Online Dating|Social Media                 -
# 10616  Fitness|Health and Wellness|Health Care|Nutrition                 -
# 10617                                        Photography                 -
#
#           status country_code state_code            region city_crunchbase  \
# 5         closed          USA         GA           Atlanta         Atlanta
# 8      operating          USA         GA           Atlanta         Atlanta
# 26     operating          USA         GA           Atlanta         Atlanta
# 29      acquired          IRL          7            Dublin          Dublin
# 33     operating          USA         GA           Atlanta         Atlanta
# ...          ...          ...        ...               ...             ...
# 10577  operating          USA         DC  Washington, D.C.      Washington
# 10583  operating          IND         16            Mumbai          Mumbai
# 10592  operating          USA         AZ           Phoenix      Scottsdale
# 10616  operating          USA         DC  Washington, D.C.      Washington
# 10617  operating          NaN        NaN               NaN             NaN
#
#        funding_rounds  founded_at first_funding_at last_funding_at  \
# 5                   1  01/05/2010       01/06/2012      01/06/2012
# 8                   1  26/08/2010       01/01/2012      01/01/2012
# 26                  3  01/08/2010       01/09/2011      01/02/2013
# 29                  4  01/12/2009       01/10/2011      09/09/2013
# 33                  1         NaN       25/04/2014      25/04/2014
# ...               ...         ...              ...             ...
# 10577               1  17/08/2013       06/10/2013      06/10/2013
# 10583               1         NaN       12/05/2015      12/05/2015
# 10592               1  15/05/2015       10/11/2015      10/11/2015
# 10616               1  03/03/2014       14/11/2014      14/11/2014
# 10617               1         NaN       12/03/2014      12/03/2014
#
#                             permalink
# 5              /organization/viacycle
# 8                  /organization/movl
# 26            /organization/xsporture
# 29             /organization/storyful
# 33             /organization/calendly
# ...                               ...
# 10577     /organization/freedom-farms
# 10583       /organization/workhorse-2
# 10592       /organization/encounter-2
# 10616  /organization/fit-body-club-co
# 10617            /organization/tapp-2
#
# [1464 rows x 19 columns]

# %% [markdown]
# Next steps: feature engineer - remove rows with no funding, create new column for length of description, remove redundant columns, split the category_list column into a distinct number of categories in order to dummy, create new column of current status that checks status codes of URLs

# %%
copy[['description']].isna().sum()
# Out:
# description    2091
# dtype: int64

# %%
help(copy.dropna)
# Out:
# Help on method dropna in module pandas.core.frame:
#
# dropna(*, axis: 'Axis' = 0, how: 'AnyAll | NoDefault' = <no_default>, thresh: 'int | NoDefault' = <no_default>, subset: 'IndexLabel' = None, inplace: 'bool' = False, ignore_index: 'bool' = False) -> 'DataFrame | None' method of pandas.core.frame.DataFrame instance
#     Remove missing values.
#
#     See the :ref:`User Guide <missing_data>` for more on which values are
#     considered missing, and how to work with missing data.
#
#     Parameters
#     ----------
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         Determine if rows or columns which contain missing values are
#         removed.
#
#         * 0, or 'index' : Drop rows which contain missing values.
#         * 1, or 'columns' : Drop columns which contain missing value.
#
#         Pass tuple or list to drop on multiple axes.
#         Only a single axis is allowed.
#
#     how : {'any', 'all'}, default 'any'
#         Determine if row or column is removed from DataFrame, when we have
#         at least one NA or all NA.
#
#         * 'any' : If any NA values are present, drop that row or column.
#         * 'all' : If all values are NA, drop that row or column.
#
#     thresh : int, optional
#         Require that many non-NA values. Cannot be combined with how.
#     subset : column label or sequence of labels, optional
#         Labels along other axis to consider, e.g. if you are dropping rows
#         these would be a list of columns to include.
#     inplace : bool, default False
#         Whether to modify the DataFrame rather than creating a new one.
#     ignore_index : bool, default ``False``
#         If ``True``, the resulting axis will be labeled 0, 1, …, n - 1.
#
#         .. versionadded:: 2.0.0
#
#     Returns
#     -------
#     DataFrame or None
#         DataFrame with NA entries dropped from it or None if ``inplace=True``.
#
#     See Also
#     --------
#     DataFrame.isna: Indicate missing values.
#     DataFrame.notna : Indicate existing (non-missing) values.
#     DataFrame.fillna : Replace missing values.
#     Series.dropna : Drop missing values.
#     Index.dropna : Drop missing indices.
#
#     Examples
#     --------
#     >>> df = pd.DataFrame({"name": ['Alfred', 'Batman', 'Catwoman'],
#     ...                    "toy": [np.nan, 'Batmobile', 'Bullwhip'],
#     ...                    "born": [pd.NaT, pd.Timestamp("1940-04-25"),
#     ...                             pd.NaT]})
#     >>> df
#            name        toy       born
#     0    Alfred        NaN        NaT
#     1    Batman  Batmobile 1940-04-25
#     2  Catwoman   Bullwhip        NaT
#
#     Drop the rows where at least one element is missing.
#
#     >>> df.dropna()
#          name        toy       born
#     1  Batman  Batmobile 1940-04-25
#
#     Drop the columns where at least one element is missing.
#
#     >>> df.dropna(axis='columns')
#            name
#     0    Alfred
#     1    Batman
#     2  Catwoman
#
#     Drop the rows where all elements are missing.
#
#     >>> df.dropna(how='all')
#            name        toy       born
#     0    Alfred        NaN        NaT
#     1    Batman  Batmobile 1940-04-25
#     2  Catwoman   Bullwhip        NaT
#
#     Keep only the rows with at least 2 non-NA values.
#
#     >>> df.dropna(thresh=2)
#            name        toy       born
#     1    Batman  Batmobile 1940-04-25
#     2  Catwoman   Bullwhip        NaT
#
#     Define in which columns to look for missing values.
#
#     >>> df.dropna(subset=['name', 'toy'])
#            name        toy       born
#     1    Batman  Batmobile 1940-04-25
#     2  Catwoman   Bullwhip        NaT
