# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('YCombinatorStartups.csv')

# %%
df
# Out:
#       Unnamed: 0     id           name           slug  \
# 0              0    325        Dropbox        dropbox
# 1              1    379         Reddit         reddit
# 2              2    383         Twitch         twitch
# 3              3    356         Scribd         scribd
# 4              4    344         Weebly         weebly
# ...          ...    ...            ...            ...
# 4405        4405  25059  Emerge Career  emerge-career
# 4406        4406  27816      OpenSight      opensight
# 4407        4407  27424         Mogara         mogara
# 4408        4408  26899        Manatee        manatee
# 4409        4409  26780        Stellar        stellar
#
#                                  former_names  \
# 0                                          []
# 1                                          []
# 2                     ['Justin.tv', 'Twitch']
# 3                                          []
# 4                                          []
# ...

# %%
df[df['name'] == 'Reddit'].T
# Out:
#                                                                         1
# Unnamed: 0                                                              1
# id                                                                    379
# name                                                               Reddit
# slug                                                               reddit
# former_names                                                           []
# small_logo_thumb_url    https://bookface-images.s3.amazonaws.com/small...
# website                                                 http://reddit.com
# all_locations                                      San Francisco, CA, USA
# long_description        Founded by Steve Huffman and Alexis Ohanian in...
# one_liner                                  The frontpage of the internet.
# team_size                                                           201.0
# highlight_black                                                     False
# ...

# %%
df.loc[df['name'] == 'Reddit', ['former_names']]
# Out:
# 1    []
# Name: former_names, dtype: object

# %%
df['former_names'][2]
# Out:
# "['Justin.tv', 'Twitch']"

# %%
pd.to_datetime(1326791708, unit='s')
# Out:
# Timestamp('2012-01-17 09:15:08')
